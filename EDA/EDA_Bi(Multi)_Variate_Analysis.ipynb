# %%
import pandas as pd
import seaborn as sns

# %%
# lets use 4 datasets.

# titanic = pd.read_csv('/content/titanic.csv')
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips.head()     # Tips given by various customers at a hotel
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head() # No of passengers travelled evey month in a flight
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris.head() # Various features of flowers, with their species category as target
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# -----------------
# # 1. Bivariate Analysis: Numerical to Numerical
#
# When both variables are numerical, we can use scatter plots, line plots, or heatmaps to visualize the relationship between them.
#
# **Scatter Plot:** Shows the relationship between two numerical variables. Each point on the scatter plot represents a pair of values from the two variables. Sns allows upto 5 variable analysis in 2D.
#
# **Line Plot:** Used when one of the numerical variables represents time or a sequential order. It shows how the other numerical variable changes over time or sequence.
#
# **Heatmap:** A graphical representation of data where values are depicted by color. In bivariate analysis, a heatmap can show the correlation between two numerical variables.

# %%
# Scatter plot for numerical to numerical analysis
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# In Scatterplots, each point is an entity.
#
# We can further analyse these entities with respect to their categories.ie, We can add one more variable under which we can observe these x,y relationship, specifically we use "hue" for it.

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# We can further add another category variable for analysis using "style" arg which are shown as X or O depending on category. Ex : Smoker

# %%
sns.scatterplot(x= "total_bill", y="tip", hue="sex", style="smoker", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# We can further add another variable as category using "size" arg where the X and O shapes representing an entity, their size varies according to the vals of feature given in size arg. ex : size feature of tips dataset, signiying no of people ate in group.

# %%
sns.scatterplot(x= "total_bill", y="tip", hue="sex", style="smoker", size="size", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# -----------
# # 2. Bivariate Analysis: Numerical to Categorical
#
# When one variable is numerical and the other is categorical, we can use box plots, violin plots, or bar plots to compare the distribution of the numerical variable across different categories.
#
# **Bar Plot:** Used to show the mean or median of a numerical variable for each category. In sns, there appears a black vertical line on on bars, indicating confidence intervals.
#
# **Box Plot:** Displays the distribution of a numerical variable for each category, showing the median, quartiles, and potential outliers.
#
# **Dis Plot/ KDE Plot:** KDE density based, dist plot used to analyse and compare PDF distribution of continus feature within each category. But its better to use kdeplot
#
# **Violin Plot:** Similar to a box plot, but it also shows the probability density of the data at different values, giving a more detailed view of the distribution.

# %% [markdown]
# ----------
# ## 2.1 BarPlots

# %%
# Box plot for numerical to categorical analysis

sns.barplot(x='day', y='total_bill', data=tips, palette="Blues") # Mean vals for each category as bar height
# Out:
# /tmp/ipython-input-1567166368.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day', y='total_bill', data=tips, palette="Blues") # Mean vals for each category as bar height
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Bargraph for titanic, pclass and age

# Here age is numerical and pclass is categorical
sns.barplot(x='pclass', y='age', data=titanic, palette='hls')
# Out:
# /tmp/ipython-input-396470296.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='pclass', y='age', data=titanic, palette='hls')
# <Axes: xlabel='pclass', ylabel='age'>

# %%
# Lets compare fare with pclass

sns.barplot(x='pclass', y='fare', data=titanic, palette='hls')
# Out:
# /tmp/ipython-input-1075687886.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='pclass', y='fare', data=titanic, palette='hls')
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# We can see that almost same amount of people travelled in pclass 2 and 3.
#
# We can also add another categorical variable using "hue" to analyse further. ex : sex

# %%
sns.barplot(x='pclass', y='fare', hue="sex", data=titanic, palette='hls')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# We can see that on an avg, women had to pay more fare in each class

# %% [markdown]
# ----------
#
# ## 2.2 BoxPlot

# %%
# Box plot for numerical to categorical analysis

# Lets keep numerical feature as Y and cat. feature as X

sns.boxplot(x='day', y='total_bill', data=tips, palette="Blues")
# Out:
# /tmp/ipython-input-2359540925.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='total_bill', data=tips, palette="Blues")
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# We can see that more business happens on Sunday.
#
# Lets now analyse titanic, specifically age(numer) within each sex(cat.)

# %%
sns.boxplot(x="sex", y ="age", data= titanic, palette ="deep")
# Out:
# /tmp/ipython-input-3423837632.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="sex", y ="age", data= titanic, palette ="deep")
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# We can see on an avg, males are older than women, to the point that outliers exist only among males.
#
# We can analyse the survival rates of each gender's age.
# lets use hue.

# %%
sns.boxplot(x="sex", y="age", hue="survived", data = titanic)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# We can see that, among males young ones survived more, and amng females old ones survived more on avg.

# %% [markdown]
# ------------
# ## 2.3 Displot

# %%
# Lets test for single variable age

sns.displot( x ="age" , data=titanic, kde=True) # remeber to set kde to true

# %%
# Remember to give categoricl variable as hue. Hence age is x, sex is hue.

sns.displot(x="age", hue="sex", data= titanic, kde = True)

# %% [markdown]
# We can see the its getting messy, Hence we can directly use kdeplot.

# %%
sns.kdeplot(x="age", hue="sex", data=titanic)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# We can see most females are of less age, compared to men. And peak of women(largest group of women) are around 23 slightly lower than men.
#
# Lets analyse age of people wrt survival rate using kdeplot.

# %%
sns.kdeplot(x= "age", hue="survived", data = titanic)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# We can see clearly, that if u are a child(low age), you have high probability of survival. And after age 10, trend reverses drastically and you have higher (infact highest) probability of dying.

# %%
# we can achieve the same using pandas feature selection

sns.kdeplot(titanic[titanic["survived"]== 0]["age"], fill=True)
sns.kdeplot(titanic[titanic["survived"]== 1]["age"], fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# ### Bivariate Analysis: Categorical to Categorical
#
# When both variables are categorical, we can use count plots, grouped bar plots, or heatmaps to visualize the relationship between the categories.
#
# **Count Plot:** Shows the counts of observations in each category.
#
# **Grouped Bar Plot:** Shows the counts of observations for combinations of categories.
#
# **Heatmap:** Can be used to visualize the contingency table of two categorical variables, showing the frequency of each combination of categories.

# %%
# Count plot for categorical to categorical analysis (using a subset of the titanic data)
sns.countplot(x='survived', hue='pclass', data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='count'>
